# %% [markdown]
# # 02 – Makrodaten Aufbereitung
#
# Ziel: Einlesen, Bereinigen und Visualisieren der Makroindikatoren.
# - DE: Destatis 42151-0004 (DGORDER Inland), 42153-0001 (Produktionsindex)
# - US: FRED DGORDER, FRED INDPRO
#
# Inkl. CCF-Analyse (Cross-Correlation Function) und ADF-Test auf Stationaritaet.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, ccf

DATA_RAW = '../data/raw/'
