# %% [markdown]
# # 02 – Macro Data Preparation
#
# Goal: Load, clean, and visualize macroeconomic indicators.
# - DE: Destatis 42151-0004 (DGORDER domestic), 42153-0001 (Production Index)
# - US: FRED DGORDER, FRED INDPRO
#
# Includes CCF analysis (Cross-Correlation Function) and ADF test for stationarity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, ccf

DATA_RAW = '../data/raw/'
